# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshh18/Computer-Vision-Practicals/blob/main/Exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image_path = '/content/Butterfly-image.jpg'
image = cv2.imread(image_path)

# %%
if image is None:
    print("Error: Could not open or find the image.")
else:
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image_hsv = cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
    plt.figure(figsize=(10, 10))

# %%
    plt.subplot(1, 4, 1)
    plt.imshow(image_rgb)
    plt.title('RGB Image')
    plt.axis('off')

    plt.subplot(1, 4, 2)
    plt.imshow(image_gray, cmap='gray')
    plt.title('Grayscale Image')
    plt.axis('off')

    plt.subplot(1, 4, 3)
    plt.imshow(image)
    plt.title('BGR Image')
    plt.axis('off')

    plt.subplot(1, 4, 4)
    plt.imshow(image)
    plt.title('HSV Image')
    plt.axis('off')
# Out:
# (-0.5, 5695.5, 3791.5, -0.5)

# %%
    plt.show()

    output_rgb_path = 'output_image_rgb.jpg'
    output_gray_path = 'output_image_gray.jpg'
    output_hsv_path = 'output_image_hsv.jpg'


    cv2.imwrite(output_rgb_path, cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR))
    cv2.imwrite(output_gray_path, image_gray)
    cv2.imwrite(output_hsv_path, image_hsv)


    print(f"RGB Image saved at: {output_rgb_path}")
    print(f"Grayscale Image saved at: {output_gray_path}")
    print(f"HSV Image saved at: {output_hsv_path}")
# Out:
# RGB Image saved at: output_image_rgb.jpg
# Grayscale Image saved at: output_image_gray.jpg
# HSV Image saved at: output_image_hsv.jpg
